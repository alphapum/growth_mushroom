# %%
# !pip uninstall torch torchvision torchaudio -y

# %%
# pip install torch==2.6.0+cu126 torchvision==0.21.0+cu126 --index-url https://download.pytorch.org/whl/cu126

# %%
from ultralytics import YOLO

# %%
import torch
import torchvision

print(torch.__version__)
print(torchvision.__version__)
# Out:
# 2.6.0+cu126
# 0.21.0+cu126

# %%
print(torch.cuda.is_available())
# Out:
# True

# %%
weights = './runs/detect/train20/weights/best.pt'
# weights = 'yolo11n.pt'

# %%
# Load a model
# model = YOLO("yolo11n-seg.yaml")  # build a new model from YAML
model = YOLO(weights)  # load a pretrained model (recommended for training)
# model = YOLO(trainp).load("yolo11n-seg.pt")  # build from YAML and transfer weights

# %%
results = model.train(data='./V89_pp_3/data.yaml', epochs=300) # Replace 'coco128.yaml' with your dataset YAML file
# Out:
# Ultralytics 8.3.107  Python-3.11.11 torch-2.6.0+cu126 CUDA:0 (NVIDIA GeForce RTX 3060, 12287MiB)
# ...

# %%
import cv2
import matplotlib.pyplot as plt

# %%
# Load a pretrained YOLOv8n model
model = YOLO(weights)

# Replace 'your_image.jpg' with the actual path to your image file
results = model.predict(source='./99.jpg', save=True, conf=0.5 ,show=True) # save=True saves the image with detections

# Show the image with predictions
for result in results:
    im_array = result.plot()
    print(result.boxes)  # print the Boxes object containing the detection bounding boxes
    print(result.masks)
    plt.imshow(cv2.cvtColor(im_array, cv2.COLOR_BGR2RGB)) # convert BGR to RGB for matplotlib
    plt.show()
# Out:
# image 1/1 d:\Project\kmutnb\growth_mushroom\99.jpg: 640x288 3 abnormals, 20.3ms
# Speed: 1.6ms preprocess, 20.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 288)
# Results saved to runs\detect\predict19
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0., 0., 0.], device='cuda:0')
# conf: tensor([0.8872, 0.6600, 0.6513], device='cuda:0')
# data: tensor([[7.7087e+01, 8.4334e+02, 2.5443e+02, 1.0123e+03, 8.8717e-01, 0.0000e+00],
#         [6.7147e+01, 1.0007e+03, 2.5329e+02, 1.0710e+03, 6.5996e-01, 0.0000e+00],
#         [2.8910e+02, 8.5651e+02, 4.6647e+02, 1.0973e+03, 6.5126e-01, 0.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1280, 576)
# shape: torch.Size([3, 6])
# xywh: tensor([[ 165.7567,  927.8347,  177.3401,  168.9828],
#         [ 160.2191, 1035.8595,  186.1448,   70.2454],
#         [ 377.7858,  976.8864,  177.3689,  240.7589]], device='cuda:0')
# xywhn: tensor([[0.2878, 0.7249, 0.3079, 0.1320],
# ...

# %%
# Process results list
for result in results:
    boxes = result.boxes  # Boxes object for bounding box outputs
    masks = result.masks  # Masks object for segmentation masks outputs
    keypoints = result.keypoints  # Keypoints object for pose outputs
    probs = result.probs  # Probs object for classification outputs
    obb = result.obb  # Oriented boxes object for OBB outputs
    result.show()  # display to screen
